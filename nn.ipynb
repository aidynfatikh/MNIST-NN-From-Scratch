# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("train.csv").to_numpy().T
paramSize, dataSize = df.shape

# %%
x = df[1:] / 255
y = df[0]

# %%
def one_hot(Y):
    one_hot_Y = np.zeros((Y.size, Y.max() + 1))
    one_hot_Y[np.arange(Y.size), Y] = 1
    one_hot_Y = one_hot_Y.T
    return one_hot_Y

def ReLU(Z, grad=False):
    if grad:
        return Z > 0
    return np.maximum(Z, 0)

def sigmoid(Z, grad=False):
    t = (1 / (1 + np.exp(-Z)))
    if grad:
        return t * (1- t)
    return t

def softmax(Z):
    A = np.exp(Z) / sum(np.exp(Z))
    return A

def get_predictions(A2):
    return np.argmax(A2, 0)

def get_accuracy(predictions, Y):
    return np.sum(predictions == Y) / Y.size

# %%
def parameters():
    W1 = np.random.rand(64, 784) - 0.5
    b1 = np.random.rand(64, 1) - 0.5
    W2 = np.random.rand(32, 64) - 0.5
    b2 = np.random.rand(32, 1) - 0.5
    W3 = np.random.rand(10, 32) - 0.5
    b3 = np.random.rand(10, 1) - 0.5
    return W1, b1, W2, b2, W3, b3

def forward(w1, b1, w2, b2, w3, b3, x):
    a1 = np.dot(w1, x) + b1
    z1 = ReLU(a1, grad=False)    
    a2 = np.dot(w2, z1) + b2
    z2 = ReLU(a2)
    a3 = np.dot(w3, z2) + b3
    z3 = softmax(a3)
    return a1, z1, a2, z2, a3, z3

def backward(a1, z1, z2, a2, w2, w3, z3, x, y):
    one_hot_Y = one_hot(y)
    loss = (z3 - one_hot_Y)
    dw3 = (1/dataSize) * np.dot(loss, z2.T)
    db3 = (1/dataSize) * np.sum(loss)
    da2 = ReLU(a2, grad=True) * np.dot(w3.T, loss)
    dw2 = (1/dataSize) * np.dot(da2, z1.T)
    db2 = (1/dataSize) * np.sum(da2)
    da1 = ReLU(a1, grad=True) * np.dot(w2.T, da2)
    dw1 = (1/dataSize) * np.dot(da1, x.T)
    db1 = (1/dataSize) * np.sum(da1)
    return dw1, db1, dw2, db2, dw3, db3

def train(x, y, epochs, lr):
    w1, b1, w2, b2, w3, b3 = parameters()
    for epoch in range(epochs+1):
        a1, z1, a2, z2, a3, z3 = forward(w1, b1, w2, b2, w3, b3, x)
        dw1, db1, dw2, db2, dw3, db3 = backward(a1, z1, z2, a2, w2, w3, z3, x, y)
        w1 -= dw1 * lr
        b1 -= db1 * lr
        w2 -= dw2 * lr
        b2 -= db2 * lr
        w3 -= dw3 * lr
        b3 -= db3 * lr

        if (epoch%10 == 0):
            pred = get_predictions(z3)
            acc = get_accuracy(pred, y)
            print(f"Epoch: {epoch}  Accuracy: {acc}")
    return w1, b1, w2, b2, w3, b3

# %%
w1, b1, w2, b2, w3, b3 = train(x, y, 2000, 0.1)
# Out:
# Epoch: 0  Accuracy: 0.07035714285714285
# Epoch: 10  Accuracy: 0.31242857142857144
# Epoch: 20  Accuracy: 0.46923809523809523
# Epoch: 30  Accuracy: 0.5705238095238095
# Epoch: 40  Accuracy: 0.635547619047619
# Epoch: 50  Accuracy: 0.6811190476190476
# Epoch: 60  Accuracy: 0.7126666666666667
# Epoch: 70  Accuracy: 0.7359523809523809
# Epoch: 80  Accuracy: 0.7548095238095238
# Epoch: 90  Accuracy: 0.7684285714285715
# Epoch: 100  Accuracy: 0.7806666666666666
# Epoch: 110  Accuracy: 0.790047619047619
# Epoch: 120  Accuracy: 0.7992619047619047
# Epoch: 130  Accuracy: 0.8069047619047619
# Epoch: 140  Accuracy: 0.813952380952381
# Epoch: 150  Accuracy: 0.8197380952380953
# Epoch: 160  Accuracy: 0.8254285714285714
# Epoch: 170  Accuracy: 0.8300952380952381
# Epoch: 180  Accuracy: 0.8348333333333333
# Epoch: 190  Accuracy: 0.8385714285714285
# Epoch: 200  Accuracy: 0.8424047619047619
# Epoch: 210  Accuracy: 0.8462380952380952
# Epoch: 220  Accuracy: 0.8495238095238096
# Epoch: 230  Accuracy: 0.8525952380952381
# Epoch: 240  Accuracy: 0.855452380952381
# Epoch: 250  Accuracy: 0.8581428571428571
# Epoch: 260  Accuracy: 0.8605
# Epoch: 270  Accuracy: 0.8626190476190476
# Epoch: 280  Accuracy: 0.8647142857142858
# Epoch: 290  Accuracy: 0.8665238095238095
# Epoch: 300  Accuracy: 0.8684761904761905
# Epoch: 310  Accuracy: 0.8710476190476191
# Epoch: 320  Accuracy: 0.8729761904761905
# Epoch: 330  Accuracy: 0.8746190476190476
# Epoch: 340  Accuracy: 0.8763333333333333
# Epoch: 350  Accuracy: 0.8779523809523809
# Epoch: 360  Accuracy: 0.8796190476190476
# Epoch: 370  Accuracy: 0.8812619047619048
# Epoch: 380  Accuracy: 0.8826428571428572
# Epoch: 390  Accuracy: 0.8839523809523809
# Epoch: 400  Accuracy: 0.8852380952380953
# Epoch: 410  Accuracy: 0.8865714285714286
# Epoch: 420  Accuracy: 0.8879047619047619
# Epoch: 430  Accuracy: 0.8891904761904762
# Epoch: 440  Accuracy: 0.8903095238095238
# Epoch: 450  Accuracy: 0.8915238095238095
# Epoch: 460  Accuracy: 0.8923333333333333
# Epoch: 470  Accuracy: 0.8932857142857142
# Epoch: 480  Accuracy: 0.8941190476190476
# Epoch: 490  Accuracy: 0.8950476190476191
# Epoch: 500  Accuracy: 0.8960714285714285
# Epoch: 510  Accuracy: 0.8971666666666667
# Epoch: 520  Accuracy: 0.8983333333333333
# Epoch: 530  Accuracy: 0.899
# Epoch: 540  Accuracy: 0.9000476190476191
# Epoch: 550  Accuracy: 0.9007142857142857
# Epoch: 560  Accuracy: 0.9016190476190477
# Epoch: 570  Accuracy: 0.9025238095238095
# Epoch: 580  Accuracy: 0.9034285714285715
# Epoch: 590  Accuracy: 0.9044047619047619
# Epoch: 600  Accuracy: 0.9052380952380953
# Epoch: 610  Accuracy: 0.9059761904761905
# Epoch: 620  Accuracy: 0.9066904761904762
# Epoch: 630  Accuracy: 0.9071904761904762
# Epoch: 640  Accuracy: 0.9077857142857143
# Epoch: 650  Accuracy: 0.9084761904761904
# Epoch: 660  Accuracy: 0.9090238095238096
# Epoch: 670  Accuracy: 0.9095
# Epoch: 680  Accuracy: 0.9101428571428571
# Epoch: 690  Accuracy: 0.9109761904761905
# Epoch: 700  Accuracy: 0.9117142857142857
# Epoch: 710  Accuracy: 0.9123333333333333
# Epoch: 720  Accuracy: 0.9128809523809523
# Epoch: 730  Accuracy: 0.9134523809523809
# Epoch: 740  Accuracy: 0.9140238095238096
# Epoch: 750  Accuracy: 0.9145952380952381
# Epoch: 760  Accuracy: 0.9151190476190476
# Epoch: 770  Accuracy: 0.9157380952380952
# Epoch: 780  Accuracy: 0.9162380952380952
# Epoch: 790  Accuracy: 0.9166666666666666
# Epoch: 800  Accuracy: 0.9170714285714285
# Epoch: 810  Accuracy: 0.9175476190476191
# Epoch: 820  Accuracy: 0.9179285714285714
# Epoch: 830  Accuracy: 0.9184523809523809
# Epoch: 840  Accuracy: 0.9187619047619048
# Epoch: 850  Accuracy: 0.9191428571428572
# Epoch: 860  Accuracy: 0.9196904761904762
# Epoch: 870  Accuracy: 0.9202380952380952
# Epoch: 880  Accuracy: 0.9207380952380952
# Epoch: 890  Accuracy: 0.9212619047619047
# Epoch: 900  Accuracy: 0.9216666666666666
# Epoch: 910  Accuracy: 0.9221190476190476
# Epoch: 920  Accuracy: 0.9225714285714286
# Epoch: 930  Accuracy: 0.9228809523809524
# Epoch: 940  Accuracy: 0.9231428571428572
# Epoch: 950  Accuracy: 0.9235952380952381
# Epoch: 960  Accuracy: 0.924
# Epoch: 970  Accuracy: 0.9243809523809524
# Epoch: 980  Accuracy: 0.9246666666666666
# Epoch: 990  Accuracy: 0.9251428571428572
# Epoch: 1000  Accuracy: 0.9256666666666666
# Epoch: 1010  Accuracy: 0.9262142857142858
# Epoch: 1020  Accuracy: 0.9265952380952381
# Epoch: 1030  Accuracy: 0.9269761904761905
# Epoch: 1040  Accuracy: 0.9275
# Epoch: 1050  Accuracy: 0.9278333333333333
# Epoch: 1060  Accuracy: 0.9283571428571429
# Epoch: 1070  Accuracy: 0.9287380952380953
# Epoch: 1080  Accuracy: 0.9291190476190476
# Epoch: 1090  Accuracy: 0.9294523809523809
# Epoch: 1100  Accuracy: 0.9298571428571428
# Epoch: 1110  Accuracy: 0.9301190476190476
# Epoch: 1120  Accuracy: 0.9304285714285714
# Epoch: 1130  Accuracy: 0.9307857142857143
# Epoch: 1140  Accuracy: 0.931047619047619
# Epoch: 1150  Accuracy: 0.9312380952380952
# Epoch: 1160  Accuracy: 0.9316666666666666
# Epoch: 1170  Accuracy: 0.9318809523809524
# Epoch: 1180  Accuracy: 0.9320952380952381
# Epoch: 1190  Accuracy: 0.9324285714285714
# Epoch: 1200  Accuracy: 0.9328333333333333
# Epoch: 1210  Accuracy: 0.9331666666666667
# Epoch: 1220  Accuracy: 0.9335
# Epoch: 1230  Accuracy: 0.9336190476190476
# Epoch: 1240  Accuracy: 0.9338571428571428
# Epoch: 1250  Accuracy: 0.9341428571428572
# Epoch: 1260  Accuracy: 0.9344523809523809
# Epoch: 1270  Accuracy: 0.9345714285714286
# Epoch: 1280  Accuracy: 0.9348333333333333
# Epoch: 1290  Accuracy: 0.9350238095238095
# Epoch: 1300  Accuracy: 0.9353333333333333
# Epoch: 1310  Accuracy: 0.9354761904761905
# Epoch: 1320  Accuracy: 0.9357619047619048
# Epoch: 1330  Accuracy: 0.9360238095238095
# Epoch: 1340  Accuracy: 0.9362619047619047
# Epoch: 1350  Accuracy: 0.9364285714285714
# Epoch: 1360  Accuracy: 0.9365714285714286
# Epoch: 1370  Accuracy: 0.9367142857142857
# Epoch: 1380  Accuracy: 0.937
# Epoch: 1390  Accuracy: 0.9371904761904762
# Epoch: 1400  Accuracy: 0.9375238095238095
# Epoch: 1410  Accuracy: 0.9376904761904762
# Epoch: 1420  Accuracy: 0.9377380952380953
# Epoch: 1430  Accuracy: 0.937952380952381
# Epoch: 1440  Accuracy: 0.9382380952380952
# Epoch: 1450  Accuracy: 0.9383333333333334
# Epoch: 1460  Accuracy: 0.9383809523809524
# Epoch: 1470  Accuracy: 0.9384761904761905
# Epoch: 1480  Accuracy: 0.9386428571428571
# Epoch: 1490  Accuracy: 0.9389285714285714
# Epoch: 1500  Accuracy: 0.939047619047619
# Epoch: 1510  Accuracy: 0.9392619047619047
# Epoch: 1520  Accuracy: 0.9395714285714286
# Epoch: 1530  Accuracy: 0.9397857142857143
# Epoch: 1540  Accuracy: 0.9399285714285714
# Epoch: 1550  Accuracy: 0.9401190476190476
# Epoch: 1560  Accuracy: 0.9403333333333334
# Epoch: 1570  Accuracy: 0.9405476190476191
# Epoch: 1580  Accuracy: 0.9407619047619048
# Epoch: 1590  Accuracy: 0.9408809523809524
# Epoch: 1600  Accuracy: 0.9410952380952381
# Epoch: 1610  Accuracy: 0.9414047619047619
# Epoch: 1620  Accuracy: 0.9416666666666667
# Epoch: 1630  Accuracy: 0.9419285714285714
# Epoch: 1640  Accuracy: 0.9421666666666667
# Epoch: 1650  Accuracy: 0.9424761904761905
# Epoch: 1660  Accuracy: 0.942595238095238
# Epoch: 1670  Accuracy: 0.9428809523809524
# Epoch: 1680  Accuracy: 0.943047619047619
# Epoch: 1690  Accuracy: 0.943
# Epoch: 1700  Accuracy: 0.9433571428571429
# Epoch: 1710  Accuracy: 0.9435714285714286
# Epoch: 1720  Accuracy: 0.9439047619047619
# Epoch: 1730  Accuracy: 0.9441190476190476
# Epoch: 1740  Accuracy: 0.9443333333333334
# Epoch: 1750  Accuracy: 0.9444523809523809
# Epoch: 1760  Accuracy: 0.9446190476190476
# Epoch: 1770  Accuracy: 0.9447619047619048
# Epoch: 1780  Accuracy: 0.9449761904761905
# Epoch: 1790  Accuracy: 0.945047619047619
# Epoch: 1800  Accuracy: 0.9452142857142857
# Epoch: 1810  Accuracy: 0.9453571428571429
# Epoch: 1820  Accuracy: 0.945595238095238
# Epoch: 1830  Accuracy: 0.9458333333333333
# Epoch: 1840  Accuracy: 0.9458809523809524
# Epoch: 1850  Accuracy: 0.946
# Epoch: 1860  Accuracy: 0.9461666666666667
# Epoch: 1870  Accuracy: 0.9464047619047619
# Epoch: 1880  Accuracy: 0.9464761904761905
# Epoch: 1890  Accuracy: 0.9466190476190476
# Epoch: 1900  Accuracy: 0.9466904761904762
# Epoch: 1910  Accuracy: 0.9467857142857142
# Epoch: 1920  Accuracy: 0.9469285714285715
# Epoch: 1930  Accuracy: 0.947047619047619
# Epoch: 1940  Accuracy: 0.9471190476190476
# Epoch: 1950  Accuracy: 0.9472380952380952
# Epoch: 1960  Accuracy: 0.9472142857142857
# Epoch: 1970  Accuracy: 0.9472857142857143
# Epoch: 1980  Accuracy: 0.9474047619047619
# Epoch: 1990  Accuracy: 0.9475476190476191
# Epoch: 2000  Accuracy: 0.9476904761904762

# %%
def over_train(w1, b1, w2, b2, w3, b3, x, y, epochs, lr):
    prev_acc = 0
    for epoch in range(epochs+1):
        a1, z1, a2, z2, a3, z3 = forward(w1, b1, w2, b2, w3, b3, x)
        dw1, db1, dw2, db2, dw3, db3 = backward(a1, z1, z2, a2, w2, w3, z3, x, y)
        w1 -= dw1 * lr
        b1 -= db1 * lr
        w2 -= dw2 * lr
        b2 -= db2 * lr
        w3 -= dw3 * lr
        b3 -= db3 * lr

        if (epoch%10 == 0):
            pred = get_predictions(z3)
            acc = get_accuracy(pred, y)
            imp = acc - prev_acc
            prev_acc = acc
            print(f"Epoch: {epoch}  Accuracy: {acc}  Improvement: {imp}")
    return w1, b1, w2, b2, w3, b3

# %%
w1, b1, w2, b2, w3, b3 = over_train(w1, b1, w2, b2, w3, b3, x, y, 300, 0.1)
# Out:
# Epoch: 0  Accuracy: 0.9972142857142857  Improvement: 0.9972142857142857
# Epoch: 10  Accuracy: 0.9972142857142857  Improvement: 0.0
# Epoch: 20  Accuracy: 0.9972142857142857  Improvement: 0.0
# Epoch: 30  Accuracy: 0.9972142857142857  Improvement: 0.0
# Epoch: 40  Accuracy: 0.9972380952380953  Improvement: 2.3809523809537048e-05
# Epoch: 50  Accuracy: 0.9972380952380953  Improvement: 0.0
# Epoch: 60  Accuracy: 0.9972380952380953  Improvement: 0.0
# Epoch: 70  Accuracy: 0.9972380952380953  Improvement: 0.0
# Epoch: 80  Accuracy: 0.9972380952380953  Improvement: 0.0
# Epoch: 90  Accuracy: 0.9972380952380953  Improvement: 0.0
# Epoch: 100  Accuracy: 0.9972380952380953  Improvement: 0.0
# Epoch: 110  Accuracy: 0.9972380952380953  Improvement: 0.0
# Epoch: 120  Accuracy: 0.9972380952380953  Improvement: 0.0
# Epoch: 130  Accuracy: 0.9972619047619048  Improvement: 2.3809523809537048e-05
# Epoch: 140  Accuracy: 0.9972619047619048  Improvement: 0.0
# Epoch: 150  Accuracy: 0.9972619047619048  Improvement: 0.0
# Epoch: 160  Accuracy: 0.9972619047619048  Improvement: 0.0
# Epoch: 170  Accuracy: 0.9972857142857143  Improvement: 2.3809523809537048e-05
# Epoch: 180  Accuracy: 0.9972857142857143  Improvement: 0.0
# Epoch: 190  Accuracy: 0.9972857142857143  Improvement: 0.0
# Epoch: 200  Accuracy: 0.9972857142857143  Improvement: 0.0
# Epoch: 210  Accuracy: 0.9972857142857143  Improvement: 0.0
# Epoch: 220  Accuracy: 0.9972857142857143  Improvement: 0.0
# Epoch: 230  Accuracy: 0.9972857142857143  Improvement: 0.0
# Epoch: 240  Accuracy: 0.9973095238095238  Improvement: 2.3809523809426025e-05
# Epoch: 250  Accuracy: 0.9973571428571428  Improvement: 4.7619047619074095e-05
# Epoch: 260  Accuracy: 0.9973571428571428  Improvement: 0.0
# Epoch: 270  Accuracy: 0.9973571428571428  Improvement: 0.0
# Epoch: 280  Accuracy: 0.9973571428571428  Improvement: 0.0
# Epoch: 290  Accuracy: 0.9973571428571428  Improvement: 0.0
# Epoch: 300  Accuracy: 0.9973571428571428  Improvement: 0.0

# %%
test = pd.read_csv("test.csv").to_numpy().T
test = test / 255

# %%
a1, z1, a2, z2, a3, z3 = forward(w1, b1, w2, b2, w3, b3, test)
test_pred = get_predictions(z3)

# %%
predictions = pd.DataFrame(test_pred)
predictions = pd.DataFrame({'ImageId': range(1, len(predictions) + 1), 'Label': predictions[0]})
predictions.to_csv("submission.csv", index=False)
